# %%
qa = {
 '早安': '你也早安',
 '掰掰': '期待下次再會',
 '晚安': '你也晚安'   
}

question = input('請問你要問什麼問題?')
qa.get(question, '我現在還不聰明，以後變聰明以後，再回答你')
# Out:
# 請問你要問什麼問題?幾歲
# '我現在還不聰明，以後變聰明以後，再回答你'

# %%
import requests
res = requests.get('https://www.ctbcbank.com/CTCBPortalWeb/toPage?id=TW_RB_CM_service_000007')

# %%
#res.text

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.text, 'lxml')
#for q in soup.select('.eventgoldtitle02 strong'):
for q in soup.select('.style01-1'):
    print(q.text)
# Out:
# 請問核卡後，收到的信用卡權益手冊，要看嗎?
# 我才剛收到卡片卻無法使用該如何處理？
# 信用卡開卡完成何時才能使用？
# 請問有哪些開卡方式?
# 為何語音開卡時，語音回覆系統無法連線，請與卡片背面發卡銀行連繫...?
# 語音開卡是否為24小時作業?
# 是否只新卡才須開卡?
# 請問刷卡一定是免簽名嗎?
# 卡片簽名是否一定要簽英文？
# 請問我何時會收到帳單？
# 我沒有收到實體帳單，請問要如何補寄?
# 我要申請電子信用卡帳單，請問該如何申請？
# 請問申請電子帳單需要費用嗎？
# 我申請電子帳單後怎麼都收不到電子帳單呢？
# 我要申請補寄電子信用卡帳單，請問該如何辦理？
# 我想變更電子郵件信箱，請問該如何辦理？
# 這個月帳單我目前未收到，如何申請補寄到我的帳單地址？
# 同一家商店只消費一筆，為什麼帳單會有兩筆以上之消費請款？
# 已經將商品退回了，為什麼還跟我收錢？
# 帳單上有一筆非本人消費該如何處理？
# 我有向你們反映爭議帳款，怎麼都沒有接到通知？什麼時候才會知道調查結果？
# 沒有出國，但帳單上有一筆國外消費，該如何處理？
# 旅館訂房、退房
# 信用卡額度是如何核定的?
# 請問貴行的固定額度是卡片共用的嗎?
# 請問貴行是否會主動幫我調高固定額度？
# 如何調高信用卡固定額度?
# 為何調高固定額度還要附財力證明?
# 如何申請調高臨時額度？
# 臨時額度調整後之金額是否也可使用循環信用繳納，並有無其它用卡需注意的呢？
# 如何辦理退貨？
# 國外郵購應注意事項
# 國外購物退稅問題
# 什麼是全球080？
# 若在國外可否用手機撥打全球080免付費電話呢？
# 如何利用ATM繳款？
# 請問語音如何查詢帳單金額？
# 該如何在郵局劃撥繳款?
# 親自臨櫃繳款方式?
# 如何辦理自動扣繳？
# 本行快速存繳款機繳款方式?
# 本行現金存款機繳款?
# 如何利用網路銀行繳交信用卡款?
# 統一超商繳款方式?
# 如何利用ｉ繳費APP繳交信用卡款?
# 我的卡片無法使用、刷不出來，是否為卡片毀損？
# 卡片毀損如何申請補發？
# 毀補後多久可補發新卡? 會不會另要收費？
# 請問我毀補卡片後，舊卡是否就無法使用?
# 遺失卡片應如何辦理掛失手續？何時補發新卡？
# 若您尚無法確定卡片是否遺失(想再找找看)時，應如何辦理？
# 卡片遺失辦理掛失，手續費如何計算？
# 請問掛失收費100元是什麼費用？
# 如果我的正卡掛失後，附卡還可以用嗎?
# 掛失卡片後，若有發生不是我的消費款，我要付負擔嗎?
# 如何使用機場停車?
# 中國信託信用卡配合的停車場為何?
# 請問停車場的營業時間是到幾點?
# 中國信託信用卡的停車優惠為何?
# 若客戶持有正附卡其停車天數如何計算? 若客戶持有正附卡其停車天數如何計算?
# 年度的停車次數或停車天數之計算時點為何?
# 若我在使用機場停車服務時，覺得權益受到損害時，應如何處理？
# 營業車(計程車)無法登錄道路救援是否可使用機場停車服務？
# 何謂旅遊平安險?
# 如果我遇到航空公司促銷，買到折扣價的機票，那是否享有保障？
# 所謂公共運輸工具是指哪些?
# 請問旅遊保險的對象是?請問旅遊保險的對象是?
# 請問如何投保旅遊保險?
# 請問班機起飛前與到達目的地後５小時內是否屬傷害險之保障期間？交通工具是否限制必須是公共運輸工具？
# 若出國旅遊包機者，可享有保障嗎？
# 如果我只是單純的購買機票，是不是一定要全額刷卡才有保險呢？
# 如何可使用機場貴賓室?
# 請問有哪些貴賓室提供服務?
# 我有刷機票或團費了，使用機場貴賓室前還需要預約嗎?
# 我要如何申請龍騰卡？需要準備甚麼資料嗎？
# 申請龍騰卡後，要怎麼使用貴賓室?
# 我沒有消費團費跟機票，但是我想要使用海外貴賓室服務，可以申請龍騰卡嗎？
# 請問我可以同一天進去同一個機場貴賓室兩次嗎?
# 如果客戶跟我太太都有中信卡，但小孩是3歲，可以帶小孩進去嗎?
# 為何有些機場貴賓室是可以攜伴，但有的不行?
# 道路救援的服務時間及範圍？
# 請問道路救援的服務專線是?
# 道路救援服務項目有哪些?
# 如何登錄/變更車籍資料?
# 如何使用道路救援服務?
# 是否所有車輛都可以登錄道路救援?
# 如果現場需要支付費用，可以用哪種方式?
# 請問語音登錄車輛廠牌時，如何轉換成數字?
# 如果在高速公路被強排，可否申請退費?
# 我持有大中華攜手飛聯名卡，為什麼無法於中信專屬平台(官網/中信卡APP)完成航空會員登錄？
# 大中華攜手飛聯名卡如何申請晉升四大航空菁英會員？
# 持有大中華卡，透過指定網站購票卻沒有折扣? 與一般信用卡網路購票價格相同？
# 「ANA極緻卡」主要的特色為何？
# ANA極緻卡本次推出的3D卡面，請問它有什麼樣的特色？
#  如何在Apple Pay 中加入中信卡？
# 哪些地方可以使用Apple Pay？
# 如何使用Apple Pay付款？
# Apple Pay適用裝置？
# Line Pay是什麼?
# 如何註冊LINE Pay帳號?
# 如何於實體商店使用LINE Pay?
# LINE Pay支付方式及可以在哪些店家使用呢?
# LINE Points折抵比例及哪裡可以折抵?
# LINE Pay支付要綁定信用卡怎麼操作呢?
# 刷LINE Pay卡消費LINE Points回饋%數為何?
# 使用LINE Pay卡消費後，多久可收到消費回饋的LINE Points?
# 我今天(11/10)LINE Pay卡完成交易及綁定，但先刷卡後才綁定這樣這筆消費可以獲得LINE Points嗎?
# LINE Pay卡解除綁定，原本的LINE Points會不見嗎?
# 原本LINE Pay卡有消費尚未請款，因卡片遺失已申請掛失處理，但部份交易店家未請款，是否會影響到LINE Points回饋??
# 如何查詢消費累積的LINE Points呢?
# 請問LINE Pay卡消費累積的LINE Points點數有使用期限嗎?
# 請問LINE Pay卡消費累積的LINE Points點數是「限時點數」還是「一般點數」?
# 我要怎麼知道這筆交易LINE Points點數的效期呢?
# LINE Points點數到期前是否會通知我呢?
# LINE Points折抵比例及哪裡可以折抵?
# 點數可以折抵消費嗎? 我要怎麼查詢哪些店家可以使用?
# 「全家便利商店」可以開啟條碼支付勾選LINE Point折抵消費，折抵方式是?
# 我習慣在網路上消費，有哪些網路店家可以折抵消費呢? 使用方式是什麼?
# LINE Points可以兌換其它商品嗎? 有百貨公司商品券或其它商品券嗎?
# 請問LINE Pay行動支付與LINE Pay卡別差是?
# 如何申請LINE Pay信用卡?
# LINE Pay信用卡5個版面，有申請限制嗎?
# 想辦一張LINE Pay信用卡給家人，版面須與正卡人相同嗎?
# LINE Pay支付要綁定信用卡怎麼操作呢?
# 如何申請中信信用卡代扣繳公用事業費用代扣繳?
# 使用中信信用卡代扣繳水電、瓦斯、電信費、公有路邊停車費、eTag自動儲值等是否需要負擔手續費?
# 使用中信信用卡代扣繳水電、瓦斯、電信費、公有路邊停車費、eTag自動儲值等是否有提供回饋?
# 只要中信卡友都可申請代扣繳水電、瓦斯、電信費、公有路邊停車費、eTag自動儲值等費用嗎?
# 如何申請中信信用卡代扣繳eTag自動儲值?
# 是否有開放中信信用卡代扣繳eTag?
# eTag自動儲值/智慧停車可以扣家人的車嗎?車主的身分有限制嗎?
# Q：市面上保險公司那麼多家、產品類型這麼多種，該如何選擇最適合自己的保險呢？
# Q：相較於跟保險業務員購買保單，透過中國信託商業銀行購買保單我可以享有什麼不一樣的服務呢？
# Q：如果購買保單之後有需要調整或變更保單內容時該怎麼辦呢？
# Q：為什麼保單上之個人基本資料有異動時一定要通知保險公司？
# Q：臨時要出國忘了買旅平險，我可以透過中國信託商業銀行來購買嗎？
# Q：除了親洽中國信託商業銀行分行的保險代理業務專區，如果不方便親自到分行時，我還可以找誰服務呢？
# Q：我要申請理賠，請問要準備那些資料呢？
# Q：我要申請理賠，保單以前是在北部的中國信託商業銀行分行購買的，但現在人在南部，誰可以協助我呢？
# 如何申請數位外幣帳戶？
# 開戶應攜帶什麼文件?
# 辦理換摺/卡片/網銀...等業務，需要到原本開戶的分行嗎?
# 存款人亡故，須徵提何種文件以辦理相關繼承事宜？
# 如何辦定存?
# 定存到期之後，會自動轉存至帳戶嗎？
# 我要如何申請/取消定存質借的功能?
# 我有一筆定存質借，請問每個月幾號要繳利息?
# 我在城中分行的綜合存款中有好幾筆定存，請問可以用補摺機補登定存明細嗎？可以到雙和分行補登嗎？
# 我昨天用電話辦一筆定存NT$20萬，請問如何知道已辦妥了？
# 我的定存還沒到期，辦理提前解約利息會怎麼算？
# 定存續存的利率和原定存利率一樣嗎？
# 何謂NCD？
# NCD可以質借嗎？
# NCD利息如何計算？
# 如何辦理掛失NCD？
# 分行是否有提供買賣外幣現鈔服務呢？
# 從外幣帳戶提領外幣現鈔，是否需支付手續費呢？
# 若我有沒用完的外幣現鈔，可否存入我的外幣帳戶呢？
# 購買人民幣現鈔金額是否有相關限制？
# 拿人民幣外幣現鈔存入外幣帳戶，有無金額限制？
# 請問貴公司的 swift code 為何?
# 若親友欲從國外匯入款項至我的銀行帳戶，我該提供什麼資料？
# 怎樣將款項匯給國外親友?
# 為何我無法使用網路銀行「台外幣/外幣轉帳」功能？有什麼身分限制嗎？
# 「台外幣/外幣轉帳」可否預約轉帳？
# 「台外幣/外幣轉帳」轉出及轉入帳號有無限制？
# 「台外幣/外幣轉帳」交易金額有無限制？
# 什麼時間可以做網銀/行動銀行換匯交易？
# 什麼是「匯率到價提醒」服務？
#
# 如何申請晶片金融卡?
# 晶片金融卡有哪些用途？
# 使用金融卡須注意哪些事項？
# 使用中國信託晶片金融卡提款、轉帳需要費用嗎？
# 晶片金融卡如何辦理掛失？
# 晶片金融卡密碼忘記或連續錯誤三次遭鎖卡時，該如何處理?
# 請問利用金融卡轉帳是否須另外申請？
# 可否將名下所有的帳戶共用一張金融卡？
# 如何申請金融卡跨國提款功能？
# 什麼是金融卡消費扣款？
# 晶片金融卡「消費扣款」服務可以在網路使用嗎？
# 持卡人使用晶片金融卡「消費扣款」服務的流程為何？
# 晶片金融卡「消費扣款」跟簽帳金融卡刷卡消費有何不同？
# 晶片金融卡受損，如何申請補發新卡？
# 中國信託簽帳金融卡可以進行分期交易嗎？
# 中國信託簽帳金融卡有刷卡金額限制嗎？
# 學生也可以辦中國信託簽帳金融卡嗎？
# 在國外使用中國信託簽帳金融卡提款密碼和國內一樣嗎？
# 中國信託簽帳金融卡可以在網路上交易嗎？
# 簽帳金融卡卡片到期，還可以用嗎？
# 中國信託信用卡享有的優惠，簽帳金融卡也有嗎？
# 我的手機號碼換了，要如何才能收到簽帳金融卡貼心消費確認簡訊？
# 中國信託簽帳金融卡可以在國外刷卡嗎？
# 我的通訊地址換了，要如何更改？
# 我申請信用卡被銀行拒絕，還可以辦簽帳金融卡嗎？
# 簽帳金融卡與一般信用卡/金融卡有何不同？
# 收到續卡之簽帳金融卡，如何開卡?
# 簽帳金融卡之繳款方式為何？
# 使用簽帳金融卡需要收取年費嗎？
# 簽帳金融卡晶片密碼連續輸入錯誤而被鎖卡時，如何處理？
# 簽帳金融卡有使用期限嗎？
# 中國信託分行/ATM據點?
# 請問營業時間?
# 各項服務手續費？
# 什麼是海外帳戶？
# 我該購屋還是租屋?
# 我需要準備多少自備款?
# 好不容易存了一桶金！掂掂我的存款…我買得起多少總價的房子呢？
# 買房子是人生重大決定！我該如何面面俱到？
# 終於來到買賣契約簽訂階段了，有什麼要注意的嗎？
# 房貸選擇這麼多種，到底哪種才適合我呢？
# 沒有申請過房貸耶…相關流程會不會很複雜？
# 購屋時需負擔哪些費用？
# 銀行是如何決定我的貸款年利率和貸款成數?
# 聽說房貸利率可分為機動計息和固定計息？差別是什麼？
# 什麼是定儲利率指數？
# 本息均攤還款和本金均攤還款有什麼不一樣？
# 申辦房貸是個重要的決定…有限制多久時間以內要清償借款嗎？
# 什麼是寬限期？寬限標的是什麼？
# 如果借款期間發生意外無法如期支付借款，怎麼辦？
# 申辦房貸需要支付什麼費用嗎？
# 如何進一步了解貸款細節？
# 如何繳款？
# 如何查詢目前每月應繳的貸款金額？
# 我的房貸採用機動計息，我該如何知道目前定儲利率指數為多少?
# 理財型房貸不動用不計息也就不用還款，那如果我有動用額度，請問會有人通知我還款嗎？
# 貸款期間是否可以部份還款？如果提前清償貸款是否會有違約金？
# 請問什麼是「個人信貸」?
# 申請「個人信貸」需要有保證人嗎?
# 我應該申請哪種貸款？
# 「循環型信貸」是什麼？和「分期型信貸」有什麼不同呢？
# 借款期限多久?
# 我可以借到多少錢？
# 透過代辦公司會有比較高的額度嗎？
# 申請「個人信貸」需要事先到中國信託開戶嗎？或一定要將款項匯到中國信託的戶頭嗎?
# 我想進一步了解貸款商品，可以透過什麼連絡管道呢?
# 申請個人信貸需要準備什麼文件嗎？
# 成功申辦「分期型信貸」後，需要負擔哪些費用？（詳依本行最新公告為準）
# 辦貸款會有哪些費用？（詳依本行最新公告為準）
# 貸款年利率如何計算？
# 什麼是定儲利率定價指數？
# 申請後需要多久才會知道是否申請成功？
# 想詢問申辦進度，可以透過什麼連絡管道呢?
# 申辦個人信貸成功後，資金什麼時候會撥入帳戶？
# 我可以指定信貸款項撥款日期嗎？
# 申辦「循環型信貸」成功後，該如何動用額度？
# 我要如何知道「分期型信貸」每期應繳款金額？
# 我要如何知道「循環型信貸」每期應繳款金額？
# 我如何知道利率變動後的新利率及應還款金額?
# 可以透過哪些管道來還款呢?
# 我想辦理自動扣繳，請問應如何申請？
# 我沒有中國信託存款帳戶，能否用其他銀行的存款帳號扣繳信貸款項？
# 辦理ACH代扣繳業務需要多久時間呢?
# 雖然「分期型信貸」每月都有「每月還款金額」的規定，請問我可以提前一次還清嗎?
# Q：如何成為財富管理客戶?
# Q：請問點數可以兌換什麼東西?
# Q：兌換點數是否要加入【台灣利樂】會員?是否要有本行網銀密碼?
# Q：於【台灣利樂】網路兌換商品，何時可收到商品?
# Q：如何與【台灣利樂】客服中心聯絡?
# Q：於【台灣利樂】兌換商品時，如何取得產品?
# Q：請問如何查詢我的訂單資料呢?
# Q：如何知道我是否訂購成功了呢?
# Q：自費購買或點數不足需補差額時應何時繳費？可用什麼方式付款？
# Q：網路銀行的好處？
# Q：網路銀行服務要如何申請呢？
# Q：網路密碼設定是否有限制？
# Q：如何保護您的密碼安全
# Q：登入網路銀行時，輸入錯誤的使用者帳號或網銀密碼超過多少次會被上鎖?
# Q：為什麼我的網路銀行會自動登出?
# Q：我可以查詢多久以前的存款明細？
# Q：如何才能使用網路轉帳功能？轉出帳號是否要約定?
# Q：網路銀行可以設定幾個約定轉出/入帳號？
# Q：若是要增加約定轉出或轉入帳號該如何做？
# Q：網路銀行轉帳之手續費如何計算？
# Q：請問繳費中心涵蓋哪些？需要額外支付手續費嗎？
# Q：為何我有海外帳戶，可是無法在網路銀行查詢到我的海外帳戶資料？
# Q：網路銀行可以進行哪些海外帳戶的相關資訊？
# Q：為何連線到網路銀行時出現憑證已過期
# Q：為何五分鐘自動登出前沒有跳出提醒的倒數計時畫面？╱WEB ATM點選查詢明細後，畫面跳一下就回到原畫面？╱點選財富點兌換後，回到原畫面沒有動靜？
# Q：我是首次登入，要如何進入註冊程序？
# Q：我忘記帳號/密碼或是密碼被鎖，該怎麼辦?
# Q：何謂「簡訊動態密碼（簡訊OTP）One Time Password」?
# Q：請問如何申請網銀非約定轉帳(OTP)功能？
# Q：請問「簡訊OTP」密碼是否有錯誤次數限制呢?
# Q：當我執行非約定轉帳交易收不到簡訊動態密碼時，怎麼辦?
# Q：請問我所接收OTP簡訊及已辦理設備認證的手機遺失了，該怎麼辦?
# Q：請問接收「簡訊動態密碼（簡訊OTP）」是否需要額外付費呢?
# Q：請問接收「簡訊OTP密碼」之行動電話號碼是否可設定為國外門號？
# Q：請問我沒有於網路銀行執行網銀交易(如：轉帳、基金等)，怎麼會接收到以貴行名義"發送的「簡訊OTP」密碼呢?"
# Q：下載中信Home Bank APP的設備有什麼限制嗎？
# Q：使用中信Home Bank APP是安全的嗎？是否有安全上的疑慮？
# Q：我已經是中信的網路銀行會員了，是否需要另外申請行動銀行
# Q：網路銀行與行動銀行登錄的使用者代號跟密碼是一樣的嗎?
# Q：為何IPAD在APP STORE找不到中信Home Bank APP可下載
# Q：中信Home Bank APP有哪些功能？
# Q：為何我無法使用網路銀行「台外幣/外幣轉帳」功能？有什麼身份限制嗎？
# Q：「台外幣/外幣轉帳」可否預約轉帳？
# Q：「台外幣/外幣轉帳」轉出及轉入帳號有無限制？
# Q：「台外幣/外幣轉帳」交易金額有無限制？
# Q：什麼時間可以做網銀/行動銀行換匯交易？
# Q：什麼是「匯率到價提醒」服務？
# Q：請問中信有哪些地方有放置ATM？
# Q：在ATM存款有金額限制嗎？
# Q：中國信託的轉帳代碼是多少?如要何透過ATM轉帳至中國信託呢?
# Q：晶片金融卡插入ATM後，為何無轉帳可選，只出現信用卡預借現金及國際金融卡提款之選項？
# Q：ATM 故障異常無法使用該怎麼辦？
# Q：於ATM交易時發生異常，如吃卡、扣帳不吐鈔…等情況或交易時ＡＴＭ突然當機？
# Q：請問ATM最新的優惠活動在哪裡可以查到？
# Q：存摺遭補摺機咬摺應該如何處理？
# Q：何謂設備認證(綁定)?
# Q：我要如何申請設備認證功能?
# Q：如何使用設備認證進行非約定轉帳?
# Q：申請設備驗證碼後，多久內需完成設備綁定？
# Q：使用網路ATM安全嗎？
# Q：使用網路ATM是否需事先申請？如何使用？
# Q：其他行庫的晶片金融卡也可以在中國信託「網路ATM」上使用嗎？
# Q：網路ATM有哪些功能？
# Q：網路ATM轉帳金額是否有限制
# Q：網路ATM轉帳交易的入帳時間為何？
# Q：我的讀卡機驅動程式已遺失或連結網路ATM出現「初始化WINSCARD.DLL失敗」訊息，該怎麼辦？
# Q：使用網路ATM轉帳成功，但卻未入帳時我該怎麼辦？
# Q：如何申請使用電話銀行?
# Q：電話銀行(語音)提供那些功能?
# Q：如何快速在電話銀行(語音)查餘額或轉帳?
